# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
"""median_year_salary = df['salary_year_avg'].median()
median_hour_salary = df['salary_hour_avg'].median()

df_filled = df
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_year_salary)
df_filled['salary_hour_avg'] = df['salary_hour_avg'].fillna(median_hour_salary)

df_unique = df_filled

df_unique = df_unique.drop_duplicates()

df_unique = df_unique.drop_duplicates(subset=['job_title', 'company_name'])
print(f"Length of orginal: {len(df)}")
print(f"Length of dropped: {len(df_unique)}")
print(f"Total dropped: {len(df) - len(df_unique)}")"""
# Out:
# Length of orginal: 785741
# Length of dropped: 508042
# Total dropped: 277699

# %%
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 11         Data Engineer                                      Data Engineer
#
#                           job_location          job_via job_schedule_type  \
# 0                        Watertown, CT  via Work Nearby         Full-time
# 11  Colorado Springs, CO   (+3 others)     via The Muse         Full-time
#
#     job_work_from_home       search_location     job_posted_date  \
# 0                False  Texas, United States 2023-06-16 13:44:15
# 11               False  Texas, United States 2023-11-03 13:06:51
#
#     job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   False                 False  United States         NaN
# 11                  False                  True  United States         NaN
#
#     salary_year_avg  salary_hour_avg          company_name  \
# ...
